# %%
# %matplotlib inline
import wordcloud
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from janome.tokenizer import Tokenizer
from PIL import Image

# %%
text = """
繊細な心、ストレスへの脆弱性、音や場の空気などへの感覚過敏、気疲れ、情報の多さを苦しく感じる、行動のスイッチを入れるのが苦手、もくもく、コツコツ、探求、マイペース、待てない、頭の疲れやすさ、整理整頓が苦手、あわてる、不安、プレッシャー、競争に弱い、忘れ物
"""

wc_base = wordcloud.WordCloud(width=1080, height=500, background_color="white", font_path=r"/System/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc" )
wc_base.generate(text)

plt.imshow(wc_base)
plt.axis("off")
# Out:
# (-0.5, 1079.5, 499.5, -0.5)

# %%
from PIL import Image, ImageOps
from IPython.display import display

# %%
im = Image.open("/Users/kks_mac01/Development/Python3.10/Data/186018009_488951298972706_5116727097580452609_n.png")
display(im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=250x250>

# %%
mini_im = im.resize((int(im.size[0] * 0.2), int(im.size[1] * 0.2)))
display(mini_im)
print(mini_im.size)
# Out:
# <PIL.Image.Image image mode=RGBA size=50x50>
# (50, 50)

# %%
num = 7
margin = 5

im = Image.open("/Users/kks_mac01/Development/Python3.10/Data/186018009_488951298972706_5116727097580452609_n.png")
im_width, im_height = im.size

#draw canvas Imaage.new(color, width, height)
canvas = Image.new("RGBA", ((im_width + margin)*num, im_height))



for i in range(num):
    canvas.paste(im, ((im_width + margin)*i, 0))
canvas
# Out:
# <PIL.Image.Image image mode=RGBA size=1785x250>

# %%
text_cloud = """
大人の発達障害、不注意、音や場の空気などに影響されやすい、気疲れ、繊細、気持ちの不安定さ、情報の多さが苦しい、行動のスイッチを入れるのが苦手、ストレスへの脆弱性、過集中、もくもく、こだわり、コツコツ、探求、マイペース、待てない、1人の世界、頭の疲れやすさ、整理整頓が苦手、あわてる、不安、プレッシャー、競争に弱い、完璧主義
"""

mask_image = np.array(Image.open("cloud.PNG"))

wc = wordcloud.WordCloud(width=1080, height=500, background_color="white", font_path=r"/System/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc",
mask=mask_image, contour_width=6, contour_color="gray", colormap="Spectral")

wc.generate(text_cloud)

plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 1279.5, 719.5, -0.5)

# %%
text_cloud = """
ひかえめ、不注意、気まぐれ、気疲れ、繊細、集中力ない、落ち着きない、LEGO、工作、生活の苦手さ、過集中、運動苦手、こだわり、コツコツ、探求、待てない、1人の世界、片づけが苦手、あわてる、不安、プレッシャー、競争に弱い、完璧主義
"""

mask_image = np.array(Image.open("cloud.PNG"))

wc = wordcloud.WordCloud(width=1080, height=500, background_color="white", font_path=r"/System/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc",
mask=mask_image, contour_width=6, contour_color="gray", colormap="Spectral")

wc.generate(text_cloud)

plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 1279.5, 719.5, -0.5)

# %%
text_cloud = """
不注意、気まぐれ、気疲れ、繊細、集中力ない、落ち着きない、LEGO、工作、生活の苦手さ、過集中、運動苦手、こだわり、コツコツ、探求、待てない、1人の世界、片づけが苦手、あわてる、不安、プレッシャー、競争に弱い、完璧主義
"""

mask_image = np.array(Image.open("cloud.PNG"))

wc = wordcloud.WordCloud(width=1080, height=500, background_color="white", font_path=r"/System/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc",
mask=mask_image, contour_width=6, contour_color="gray", colormap="Spectral")

wc.generate(text_cloud)

plt.imshow(wc)
plt.axis("off")
